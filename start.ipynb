# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     Unnamed: 0  cgpa
# 0            0   6.8
# 1            1   5.9
# 2            2   5.3
# 3            3   7.4
# 4            4   5.8
# ..         ...   ...
# 95          95   4.3
# 96          96   4.4
# 97          97   6.7
# 98          98   6.3
# 99          99   6.2
#
# [100 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     Unnamed: 0  cgpa
# 85          85   5.8
# 74          74   6.7
# 94          94   4.7
# 76          76   4.9
# 95          95   4.3
# ..         ...   ...
# 9            9   5.1
# 64          64   7.0
# 60          60   6.9
# 28          28   5.2
# 98          98   6.3
#
# [90 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.20385201e+00, -9.75305782e-02],
#        [ 8.25738595e-01,  6.92467105e-01],
#        [ 1.51321754e+00, -1.06308330e+00],
#        [ 8.94486489e-01, -8.87528262e-01],
#        [ 1.54759148e+00, -1.41419338e+00],
#        [-1.54606375e+00,  1.04357719e+00],
#        [-8.24210864e-01,  9.55799666e-01],
#        [-9.61706652e-01, -8.87528262e-01],
#        [ 3.78877283e-01,  1.21913223e+00],
#        [-1.02357976e-01, -6.24195700e-01],
#        [-5.49219287e-01, -9.75305782e-01],
#        [ 4.47625177e-01,  3.41357024e-01],
#        [-8.58584811e-01, -7.99750741e-01],
#        [ 1.41009569e+00,  1.39468727e+00],
#        [-1.03045455e+00,  6.04689585e-01],
#        [ 5.85120965e-01, -7.99750741e-01],
#        [-1.37419402e+00,  7.80244626e-02],
#        [ 1.27259991e+00, -1.85308099e-01],
#        [-4.11723499e-01,  5.16912064e-01],
#        [ 3.51378125e-02, -9.75305782e-01],
#        [ 3.10129389e-01, -9.75305782e-01],
#        [ 1.03198228e+00, -8.87528262e-01],
#        [ 4.13251230e-01,  7.80244626e-02],
#        [ 7.63865490e-04, -2.11641355e+00],
#        [ 1.06635622e+00, -4.48640660e-01],
#        [-1.68355954e+00, -9.75305782e-03],
#        [-1.51168980e+00, -1.85308099e-01],
#        [-3.08601658e-01, -4.48640660e-01],
#        [ 1.68508727e+00,  2.53579503e-01],
#        [ 5.50747018e-01,  8.68022146e-01],
#        [-1.71793349e+00,  7.80244626e-01],
#        [-2.74227711e-01,  1.48246479e+00],
#        [-7.21089023e-01,  9.55799666e-01],
#        [-1.23669823e+00,  1.65801983e-01],
#        [-7.89836917e-01,  7.80244626e-02],
#        [-1.13357639e+00, -2.29196859e+00],
#        [-3.36100816e-02, -4.48640660e-01],
#        [ 6.53868859e-01,  2.27246247e+00],
#        [-2.39853764e-01,  7.80244626e-01],
#        [-1.20232428e+00, -7.11973221e-01],
#        [ 1.44446964e+00, -6.24195700e-01],
#        [-9.27332705e-01, -1.06308330e+00],
#        [-1.47731586e+00, -7.99750741e-01],
#        [ 1.61633938e+00,  6.92467105e-01],
#        [ 1.34134780e+00, -8.87528262e-01],
#        [-3.42975605e-01, -8.87528262e-01],
#        [-1.44294191e+00,  1.65801983e-01],
#        [-1.27107218e+00,  4.29134544e-01],
#        [ 8.60112542e-01, -9.75305782e-01],
#        [ 2.41381495e-01,  5.16912064e-01],
#        [ 1.30697385e+00, -1.32641586e+00],
#        [-1.30544612e+00, -4.48640660e-01],
#        [ 2.07007548e-01,  1.65801983e-01],
#        [ 1.72633601e-01,  1.65801983e+00],
#        [-8.92958758e-01, -1.06308330e+00],
#        [ 1.58196543e+00, -1.32641586e+00],
#        [ 9.28860436e-01,  1.21913223e+00],
#        [-1.71105870e-01,  7.80244626e-02],
#        [-2.05479817e-01,  1.39468727e+00],
#        [ 6.19494912e-01, -1.67752594e+00],
#        [ 1.16947807e+00, -1.85308099e-01],
#        [ 5.16373071e-01,  1.92135239e+00],
#        [ 9.63234383e-01,  1.65801983e-01],
#        [-6.86715075e-01,  1.48246479e+00],
#        [-1.64918559e+00, -5.36418180e-01],
#        [-1.36731923e-01, -5.36418180e-01],
#        [ 6.95117596e-02,  9.55799666e-01],
#        [ 1.37572175e+00,  1.21913223e+00],
#        [-1.09920244e+00, -1.67752594e+00],
#        [ 6.88242806e-01,  3.41357024e-01],
#        [ 1.03885707e-01,  2.09690743e+00],
#        [ 7.91364648e-01, -8.87528262e-01],
#        [-1.06482849e+00, -6.24195700e-01],
#        [-9.96080599e-01,  1.04357719e+00],
#        [-3.77349552e-01, -1.15086082e+00],
#        [ 1.10073017e+00,  5.16912064e-01],
#        [-5.83593234e-01,  7.80244626e-02],
#        [ 9.97608330e-01,  5.16912064e-01],
#        [-4.46097446e-01,  1.92135239e+00],
#        [ 1.47884359e+00,  7.80244626e-01],
#        [-6.52341128e-01, -1.76530347e+00],
#        [-5.14845340e-01,  7.80244626e-01],
#        [ 1.23822596e+00, -7.11973221e-01],
#        [-6.17967181e-01,  9.55799666e-01],
#        [-1.58043770e+00, -9.75305782e-02],
#        [-1.40856796e+00, -7.11973221e-01],
#        [ 4.81999124e-01,  9.55799666e-01],
#        [ 3.44503336e-01,  8.68022146e-01],
#        [-7.55462970e-01, -6.24195700e-01],
#        [ 1.65071332e+00,  3.41357024e-01]])

# %%
x_test=scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-1.29731728,  0.22825396],
#        [ 1.0166112 ,  0.70878861],
#        [ 0.48554565,  1.54972425],
#        [-0.34898593, -1.21335   ],
#        [ 0.33381263, -0.37241436],
#        [-1.10765101, -1.81401831],
#        [-1.60078331,  0.82892227],
#        [ 0.97867795, -0.73281534],
#        [ 1.43387699,  0.94905594],
#        [ 0.10621311, -0.13214703]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(clf, f)

# %%
from google.colab import files

# %%
files.download('model.pkl')

# %%
files.download('start.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-22433d793257> in <cell line: 0>()
# ----> 1 files.download('start.ipynb')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: start.ipynb

# %%
from google.colab import files

# %%
get_ipython().notebook.save_checkpoint()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-37effeaf2c43> in <cell line: 0>()
# ----> 1 get_ipython().notebook.save_checkpoint()
#
# AttributeError: 'Shell' object has no attribute 'notebook'
